# %% [markdown]
# # Notebook color rendering probe
# Each row tests a different method. This notebook contains only synthetic text.

# %% [markdown]
# Metadata only: AI question should be blue if GitHub reads nbinlineai metadata.

# %% [markdown]
# Metadata only: AI answer should be green if GitHub reads nbinlineai metadata.

# %% [markdown]
# <div style="background-color:#eaf2ff;border-left:4px solid #0969da;padding:12px">Inline CSS: this block should have a blue background and border.</div>

# %% [markdown]
# <div style="background-color:#e8f5e9;border-left:4px solid #2da44e;padding:12px">Inline CSS: this block should have a green background and border.</div>

# %% [markdown]
# <style>.gh-probe { background-color: #fff4ce; border-left: 4px solid #bf8700; padding: 12px; }</style>
# <div class="gh-probe">Style tag and class: this block should be yellow.</div>

# %% [markdown]
# <table bgcolor="#eaf2ff"><tr><td>HTML bgcolor attribute: this table should be blue.</td></tr></table>

# %% [markdown]
# <img src="..." alt="blue square"/> SVG image in Markdown source.

# %% [markdown]
# 🟦 **AI question** — plain Markdown marker.
#
# 🟩 **AI answer** — plain Markdown marker.

# %%
# Synthetic saved HTML output
# Out:
# Saved HTML output with blue background.
